# %% [markdown]
# <a href="https://colab.research.google.com/github/srojassu/MetNumUN2022II/blob/main/Lab4/group32SymPyLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials

# %% [markdown]
# **My example**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 + 41*x**9 + 408*x**8 - 2758*x**7 - 55547*x**6 - 73311*x**5 + 1405242*x**4 + 2667708*x**3 - 11873304*x**2 - 13063680*x + 20995200

p, r = div(p,  x+18)

print(p)
print(r)

p, r = div(p,  x+15)

print(p)
print(r)

p, r = div(p,  x+12)

print(p)
print(r)

p, r = div(p,  x+6)

print(p)
print(r)

p, r = div(p,  x+5)

print(p)
print(r)
# Out:
# x**9 + 23*x**8 - 6*x**7 - 2650*x**6 - 7847*x**5 + 67935*x**4 + 182412*x**3 - 615708*x**2 - 790560*x + 1166400
# 0
# x**8 + 8*x**7 - 126*x**6 - 760*x**5 + 3553*x**4 + 14640*x**3 - 37188*x**2 - 57888*x + 77760
# 0
# x**7 - 4*x**6 - 78*x**5 + 176*x**4 + 1441*x**3 - 2652*x**2 - 5364*x + 6480
# 0
# x**6 - 10*x**5 - 18*x**4 + 284*x**3 - 263*x**2 - 1074*x + 1080
# 0
# x**5 - 15*x**4 + 57*x**3 - x**2 - 258*x + 216
# 0

# %%
p = x**10 + 41*x**9 + 408*x**8 - 2758*x**7 - 55547*x**6 - 73311*x**5 + 1405242*x**4 + 2667708*x**3 - 11873304*x**2 - 13063680*x + 20995200



p, r = div(p,  x-13)

print(p)
print(r)
# Out:
# x**9 + 54*x**8 + 1110*x**7 + 11672*x**6 + 96189*x**5 + 1177146*x**4 + 16708140*x**3 + 219873528*x**2 + 2846482560*x + 36991209600
# 480906720000

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization

# %% [markdown]
# **My example**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 + 41*x**9 + 408*x**8 - 2758*x**7 - 55547*x**6 - 73311*x**5 + 1405242*x**4 + 2667708*x**3 - 11873304*x**2 - 13063680*x + 20995200)
# Out:
# (x - 9)*(x - 4)*(x - 3)*(x - 1)*(x + 2)*(x + 5)*(x + 6)*(x + 12)*(x + 15)*(x + 18)

# %% [markdown]
# ## SymPy’s solvers

# %% [markdown]
# **My own example**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 + 41*x**9 + 408*x**8 - 2758*x**7 - 55547*x**6 - 73311*x**5 + 1405242*x**4 + 2667708*x**3 - 11873304*x**2 - 13063680*x + 20995200, 0), x)
# Out:
# FiniteSet(-18, -15, -12, -6, -5, -2, 1, 3, 4, 9)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi
x = Symbol('x')
solveset(Eq(x**2 - (sqrt(6)+pi)*x - (sqrt(6)*pi) , 0), x)
# Out:
# FiniteSet(sqrt(6)/2 + pi/2 + sqrt(6 + pi**2 + 6*sqrt(6)*pi)/2, -sqrt(6 + pi**2 + 6*sqrt(6)*pi)/2 + sqrt(6)/2 + pi/2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 + 41*x**9 + 408*x**8 - 2758*x**7 - 55547*x**6 - 73311*x**5 + 1405242*x**4 + 2667708*x**3 - 11873304*x**2 - 13063680*x + 20995200,domain='GF(3)')
# Out:
# x**6*(x - 1)**4

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations

# %% [markdown]
# **My own example**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x3, x4, y3, y4, z3, z4 = symbols("x3 x4 y3 y4 z3 z4", real=True)  
x = x3 + I*x4
y = y3 + I*y4
z = z3 + I*z4

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))

w=N(1/(pi + I), 20)
print('w=',w)
# Out:
# (x3 + I*x4)*(y3 + I*y4)*(z3 + I*z4)
# x3*y3*z3 + I*x3*y3*z4 + I*x3*y4*z3 - x3*y4*z4 + I*x4*y3*z3 - x4*y3*z4 - x4*y4*z3 - I*x4*y4*z4
# x3*y3*z3 + I*x3*y3*z4 + I*x3*y4*z3 - x3*y4*z4 + I*x4*y3*z3 - x4*y3*z4 - x4*y4*z3 - I*x4*y4*z4
# x3*y3*z3 + I*x3*y3*z4 + I*x3*y4*z3 - x3*y4*z4 + I*x4*y3*z3 - x4*y3*z4 - x4*y4*z3 - I*x4*y4*z4
# w= 0.28902548222223624241 - 0.091999668350375232456*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje

# %% [markdown]
# **My own example**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate

# %% [markdown]
# **My own example**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**2 * sin(x)**7, x)
# Out:
# -x**2*sin(x)**6*cos(x) - 2*x**2*sin(x)**4*cos(x)**3 - 8*x**2*sin(x)**2*cos(x)**5/5 - 16*x**2*cos(x)**7/35 + 4322*x*sin(x)**7/3675 + 1636*x*sin(x)**5*cos(x)**2/525 + 304*x*sin(x)**3*cos(x)**4/105 + 32*x*sin(x)*cos(x)**6/35 + 4322*sin(x)**6*cos(x)/3675 + 37384*sin(x)**4*cos(x)**3/11025 + 181456*sin(x)**2*cos(x)**5/55125 + 413312*cos(x)**7/385875

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**2 * sin(x)**7, (x,1,6))
# Out:
# -5937088*cos(6)**7/385875 - 2993744*sin(6)**2*cos(6)**5/55125 + 192*sin(6)*cos(6)**6/35 - 1636*sin(1)**5*cos(1)**2/525 - 756416*sin(6)**4*cos(6)**3/11025 - 4322*sin(1)**7/3675 + 608*sin(6)**3*cos(6)**4/35 - 304*sin(1)**3*cos(1)**4/105 - 15334*sin(1)**4*cos(1)**3/11025 - 93256*sin(1)**2*cos(1)**5/55125 - 647*sin(1)**6*cos(1)/3675 + 3272*sin(6)**5*cos(6)**2/175 - 32*sin(1)*cos(1)**6/35 - 127978*sin(6)**6*cos(6)/3675 - 236912*cos(1)**7/385875 + 8644*sin(6)**7/1225

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(x**2 * sin(x)**7, (x,1,6)))
# Out:
# -18.0844232006779
